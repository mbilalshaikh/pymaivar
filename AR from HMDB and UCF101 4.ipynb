# %%
cd ..
# Out:
# /home/muhammadbsheikh/workspace/try

# %%
# cnn2fft
# check PyTorch versions
# import standard PyTorch modules
import os
os.environ['CUDA_VISIBLE_DEVICES']="0"
import torch
import torch.nn as nn
import torch.nn.functional as F
import pretrainedmodels
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter # TensorBoard support

# import torchvision module to handle image manipulation
import torchvision
from torchvision import datasets, models, transforms
import torchvision.transforms as transforms
from torch.autograd import Variable

# calculate train time, writing train data to files etc.
import time
import numpy as np
import pandas as pd
import json
from tqdm import tqdm
from IPython.display import clear_output


from efficientnet_pytorch import EfficientNet

from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import scipy
import scipy.fft



print(torch.__version__)
print(torchvision.__version__)

#device = torch.device("cuda")
torch.set_printoptions(linewidth=120)
torch.set_grad_enabled(True)     # On by default, leave it here for clarity
# torch.cuda.current_device()

# Helper class, help track loss, accuracy, epoch time, run time, 
# hyper-parameters etc. Also record to TensorBoard and write into csv, json

# import modules to build RunBuilder and RunManager helper classes
from collections  import OrderedDict
from collections import namedtuple
from itertools import product

# Read in the hyper-parameters and return a Run namedtuple containing all the 
# combinations of hyper-parameters
class RunBuilder():
  @staticmethod
  def get_runs(params):

    Run = namedtuple('Run', params.keys())

    runs = []
    for v in product(*params.values()):
      runs.append(Run(*v))
    
    return runs

class RunManager():

  def __init__(self):

    # tracking every epoch count, loss, accuracy, time
    self.epoch_count = 0
    self.epoch_loss = 0
    self.epoch_num_correct = 0
    
    self.epoch_val_loss = 0
    self.epoch_val_num_correct = 0
    self.epoch_start_time = None

    # tracking every run count, run data, hyper-params used, time
    self.run_params = None
    self.run_count = 0
    self.run_data = []
    self.run_start_time = None

    # record model, loader and TensorBoard 
    self.network = None
    self.loader = None
    self.vloader = None
    self.tb = None

  # record the count, hyper-param, model, loader of each run
  # record sample images and network graph to TensorBoard  
  def begin_run(self, run, network, loader,vloader):

    self.run_start_time = time.time()

    self.run_params = run
    self.run_count += 1

    self.network = network
    self.loader = loader
    self.vloader = vloader
    self.tb = SummaryWriter(comment=f'-{run}')

    images, labels = next(iter(self.loader))
    images, labels = images.to(device), labels.to(device)
    grid = torchvision.utils.make_grid(images)

    self.tb.add_image('images', grid)
    self.tb.add_graph(self.network, images)

  # when run ends, close TensorBoard, zero epoch count
  def end_run(self):
    self.tb.close()
    self.epoch_count = 0

  # zero epoch count, loss, accuracy, 
  def begin_epoch(self):
    self.epoch_start_time = time.time()

    self.epoch_count += 1
    self.epoch_loss = 0
    self.epoch_num_correct = 0

  # 
  def end_epoch(self):
    # calculate epoch duration and run duration(accumulate)
    epoch_duration = time.time() - self.epoch_start_time
    run_duration = time.time() - self.run_start_time

    # record epoch loss and accuracy
    loss = self.epoch_loss / len(self.loader.dataset)
    accuracy = self.epoch_num_correct / len(self.loader.dataset)
    
    vloss = self.epoch_val_loss / len(self.vloader.dataset)
    vaccuracy = self.epoch_val_num_correct / len(self.vloader.dataset)

    # Record epoch loss and accuracy to TensorBoard 
    self.tb.add_scalar('Loss', loss, self.epoch_count)
    self.tb.add_scalar('Accuracy', accuracy, self.epoch_count)
    
    # Record epoch loss and accuracy to TensorBoard 
    self.tb.add_scalar('vLoss', vloss, self.epoch_count)
    self.tb.add_scalar('vAccuracy', vaccuracy, self.epoch_count)

    # Record params to TensorBoard
    for name, param in self.network.named_parameters():
      self.tb.add_histogram(name, param, self.epoch_count)
      self.tb.add_histogram(f'{name}.grad', param.grad, self.epoch_count)
    
    # Write into 'results' (OrderedDict) for all run related data
    results = OrderedDict()
    results["run"] = self.run_count
    results["epoch"] = self.epoch_count
    results["loss"] = loss
    results["val_loss"] = self.epoch_val_loss
    results["val_accuracy"] = self.epoch_val_num_correct
    results["accuracy"] = accuracy
    results["epoch duration"] = epoch_duration
    results["run duration"] = run_duration

    # Record hyper-params into 'results'
    for k,v in self.run_params._asdict().items(): results[k] = v
    self.run_data.append(results)
    df = pd.DataFrame.from_dict(self.run_data, orient = 'columns')

    # display epoch information and show progress
    clear_output(wait=True)
    #display(df)

  def track_vloss_vacc(self, loss, acc):
    # multiply batch size so variety of batch sizes can be compared
    self.epoch_val_loss = loss.item()
    self.epoch_val_num_correct = acc
    
    
    # accumulate loss of batch into entire epoch loss
  def track_loss(self, loss):
    # multiply batch size so variety of batch sizes can be compared
    self.epoch_loss += loss.item() * self.loader.batch_size

  # accumulate number of corrects of batch into entire epoch num_correct
  def track_num_correct(self, preds, labels):
    self.epoch_num_correct += self._get_num_correct(preds, labels)

  @torch.no_grad()
  def _get_num_correct(self, preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()
  
  # save end results of all runs into csv, json for further a
  def save(self, fileName):

    pd.DataFrame.from_dict(
        self.run_data, 
        orient = 'columns',
    ).to_csv(f'{fileName}.csv')

    with open(f'{fileName}.json', 'w', encoding='utf-8') as f:
      json.dump(self.run_data, f, ensure_ascii=False, indent=4)

#set device
if torch.cuda.is_available():
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(torch.cuda.get_device_properties(device),torch.cuda.set_device(device),torch.cuda.current_device())

#Hyperparameters

#input_size
#num_classes = 50
#learning_rate = 0.00005
BATCH_SIZE = 32
epochs = 1

# put all hyper params into a OrderedDict, easily expandable
params = OrderedDict(
    exp='6',
    lr = [0.0005],#,0.001,0.0001,0.00001], # 0.001
    batch_size = [BATCH_SIZE], # 1000
    shuffle = [True] # True,False
    # Optimizer = [Adam,NAdam,RMSProp,Adamax,SGD,Adagrad,Adadelta]
)

TRAIN_DATA_PATH = "./datax/8/train/"
TEST_DATA_PATH = "./datax/8/test/"

transform = transforms.Compose([    
    transforms.Resize(299),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225] )
    ])

train_data = torchvision.datasets.ImageFolder(root=TRAIN_DATA_PATH, transform=transform)
test_data = torchvision.datasets.ImageFolder(root=TEST_DATA_PATH, transform=transform)



train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True,  num_workers=4)
test_data_loader = torch.utils.data.DataLoader(test_data, batch_size=16, shuffle=True,  num_workers=4)

m = RunManager()


#prepare model
model_name = 'inceptionresnetv2' # could be fbresnet152 or inceptionresnetv2
model = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained='imagenet')

model.last_linear = nn.Identity() #freeze the model
#num_ftrs = model.last_linear.in_features
#model.last_linear = nn.Linear(num_ftrs, 50)

for p in model.parameters():
    p.requires_grad =False
    
#num_ftrs = model.last_linear.in_features

    # Here the size of each output sample is set to 2.
    # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
#model.fc = nn.Linear(num_ftrs, 50)

PATH = "models/IRv2.pt"

torch.save(model,PATH)
#model = torch.load(PATH)

optimizer = optim.Adam(model.parameters(), lr=0.0005)

def train(model,loader,epochs=60):
    model.to(device)
    model.train()   
    print('Training...')
    for epoch in range(epochs):
        start = time.time()
        model.train()
        m.begin_epoch()
        running_loss=0

        for i,batch in enumerate(loader,0):
                images = batch[0]
                labels = batch[1]
                images = images.to(device)
                labels = labels.to(device)
                
                preds = model(images)
                loss = F.cross_entropy(preds, labels) # Adam, SGD, RSPROP

                optimizer.zero_grad()
                loss = Variable(loss, requires_grad = True)
                loss.backward()
                optimizer.step()

                running_loss+=loss.data

                if i%10==9:
                    end=time.time()
                    print ('[epoch %d,imgs %5d] loss: %.7f  time: %0.3f s'%(epoch+1,(i+1)*4,running_loss/100,(end-start)))
                    #tb.add_scalar('Loss', loss, epoch+1)
                    start=time.time()
                    running_loss=0    
    

train(model,train_data_loader)


def extract_features(model,dl):
    lbls = []
    model.eval()
    device = 'cuda:0'
    model.cuda(device)
    with torch.no_grad():
        features = None
        for batch in tqdm(dl, disable=True):
            
            images = batch[0]
            labels = batch[1]
            images = images.to(device)
            #labels = labels.to(device)

            output = model(images)
            lbls.append(labels)
            #print(labels)

            if features is not None:
                features = torch.cat((features, output), 0)

            else:
                features = output        
            

    return features.cpu().numpy(),lbls


def flatten_list(t):
    flat_list = [item for sublist in t for item in sublist]
    flat_list = np.array(flat_list)
    return flat_list



print('Extracting Features...')
feat,lbls = extract_features(model,train_data_loader)
# randomforest, logisticregression, SVM , KNN, LD,
# Out:
# 1.8.1
# 0.9.1
# _CudaDeviceProperties(name='GeForce GTX 1080 Ti', major=6, minor=1, total_memory=11178MB, multi_processor_count=28) None 0
# Training...
# [epoch 1,imgs    40] loss: 0.7386895  time: 2.912 s
# [epoch 1,imgs    80] loss: 0.7385045  time: 1.876 s
# [epoch 1,imgs   120] loss: 0.7383262  time: 1.877 s
# [epoch 1,imgs   160] loss: 0.7446477  time: 1.883 s
# [epoch 1,imgs   200] loss: 0.7389404  time: 1.884 s
# [epoch 1,imgs   240] loss: 0.7428309  time: 1.883 s
# [epoch 1,imgs   280] loss: 0.7399807  time: 1.879 s
# [epoch 1,imgs   320] loss: 0.7392285  time: 1.881 s
# [epoch 1,imgs   360] loss: 0.7380611  time: 1.872 s
# [epoch 1,imgs   400] loss: 0.7409830  time: 1.879 s
# [epoch 1,imgs   440] loss: 0.7386407  time: 1.897 s
# [epoch 1,imgs   480] loss: 0.7360366  time: 1.887 s
# [epoch 1,imgs   520] loss: 0.7408078  time: 1.882 s
# [epoch 1,imgs   560] loss: 0.7419208  time: 1.887 s
# [epoch 1,imgs   600] loss: 0.7419127  time: 1.325 s
# [epoch 1,imgs   640] loss: 0.7400951  time: 1.888 s
# [epoch 1,imgs   680] loss: 0.7370915  time: 1.884 s
# [epoch 1,imgs   720] loss: 0.7416403  time: 1.886 s
# [epoch 1,imgs   760] loss: 0.7406655  time: 1.890 s
# [epoch 1,imgs   800] loss: 0.7337304  time: 1.882 s
# [epoch 1,imgs   840] loss: 0.7437429  time: 1.887 s
# [epoch 1,imgs   880] loss: 0.7413996  time: 1.885 s
# [epoch 1,imgs   920] loss: 0.7387410  time: 1.879 s
# [epoch 1,imgs   960] loss: 0.7350022  time: 1.882 s
# [epoch 1,imgs  1000] loss: 0.7430988  time: 1.892 s
# [epoch 1,imgs  1040] loss: 0.7404183  time: 1.903 s
# [epoch 1,imgs  1080] loss: 0.7372386  time: 1.891 s
# [epoch 1,imgs  1120] loss: 0.7432023  time: 1.896 s
# [epoch 1,imgs  1160] loss: 0.7374150  time: 1.889 s
# [epoch 1,imgs  1200] loss: 0.7373849  time: 1.886 s
# [epoch 2,imgs    40] loss: 0.7417581  time: 2.326 s
# [epoch 2,imgs    80] loss: 0.7401593  time: 1.888 s
# [epoch 2,imgs   120] loss: 0.7401478  time: 1.887 s
# [epoch 2,imgs   160] loss: 0.7382603  time: 1.889 s
# [epoch 2,imgs   200] loss: 0.7417206  time: 1.892 s
# [epoch 2,imgs   240] loss: 0.7375191  time: 1.889 s
# [epoch 2,imgs   280] loss: 0.7353459  time: 1.888 s
# [epoch 2,imgs   320] loss: 0.7476565  time: 1.884 s
# [epoch 2,imgs   360] loss: 0.7444450  time: 1.887 s
# [epoch 2,imgs   400] loss: 0.7385486  time: 1.885 s
# [epoch 2,imgs   440] loss: 0.7405279  time: 1.892 s
# [epoch 2,imgs   480] loss: 0.7380761  time: 1.889 s
# [epoch 2,imgs   520] loss: 0.7434483  time: 1.886 s
# [epoch 2,imgs   560] loss: 0.7371686  time: 1.887 s
# [epoch 2,imgs   600] loss: 0.7398002  time: 1.321 s
# [epoch 2,imgs   640] loss: 0.7419194  time: 1.864 s
# [epoch 2,imgs   680] loss: 0.7385505  time: 1.873 s
# [epoch 2,imgs   720] loss: 0.7366533  time: 1.873 s
# [epoch 2,imgs   760] loss: 0.7374943  time: 1.873 s
# [epoch 2,imgs   800] loss: 0.7402682  time: 1.876 s
# [epoch 2,imgs   840] loss: 0.7418551  time: 1.871 s
# [epoch 2,imgs   880] loss: 0.7382374  time: 1.872 s
# [epoch 2,imgs   920] loss: 0.7365478  time: 1.875 s
# [epoch 2,imgs   960] loss: 0.7405206  time: 1.873 s
# [epoch 2,imgs  1000] loss: 0.7381390  time: 1.874 s
# [epoch 2,imgs  1040] loss: 0.7398294  time: 1.876 s
# [epoch 2,imgs  1080] loss: 0.7397366  time: 1.881 s
# [epoch 2,imgs  1120] loss: 0.7408519  time: 1.874 s
# [epoch 2,imgs  1160] loss: 0.7378586  time: 1.880 s
# [epoch 2,imgs  1200] loss: 0.7372496  time: 1.872 s
# [epoch 3,imgs    40] loss: 0.7366693  time: 2.259 s
# [epoch 3,imgs    80] loss: 0.7405552  time: 1.880 s
# [epoch 3,imgs   120] loss: 0.7361544  time: 1.876 s
# [epoch 3,imgs   160] loss: 0.7393402  time: 1.878 s
# [epoch 3,imgs   200] loss: 0.7361344  time: 1.879 s
# [epoch 3,imgs   240] loss: 0.7393951  time: 1.877 s
# [epoch 3,imgs   280] loss: 0.7358398  time: 1.875 s
# [epoch 3,imgs   320] loss: 0.7418906  time: 1.873 s
# [epoch 3,imgs   360] loss: 0.7433165  time: 1.881 s
# [epoch 3,imgs   400] loss: 0.7394196  time: 1.872 s
# [epoch 3,imgs   440] loss: 0.7394254  time: 1.876 s
# [epoch 3,imgs   480] loss: 0.7358843  time: 1.880 s
# [epoch 3,imgs   520] loss: 0.7400864  time: 1.880 s
# [epoch 3,imgs   560] loss: 0.7428199  time: 1.875 s
# [epoch 3,imgs   600] loss: 0.7387176  time: 1.266 s
# [epoch 3,imgs   640] loss: 0.7356843  time: 1.858 s
# [epoch 3,imgs   680] loss: 0.7368775  time: 1.870 s
# [epoch 3,imgs   720] loss: 0.7381828  time: 1.876 s
# [epoch 3,imgs   760] loss: 0.7434303  time: 1.889 s
# [epoch 3,imgs   800] loss: 0.7407817  time: 1.889 s
# [epoch 3,imgs   840] loss: 0.7357156  time: 1.888 s
# [epoch 3,imgs   880] loss: 0.7388336  time: 1.902 s
# [epoch 3,imgs   920] loss: 0.7439187  time: 1.886 s
# [epoch 3,imgs   960] loss: 0.7377443  time: 1.889 s
# [epoch 3,imgs  1000] loss: 0.7421116  time: 1.887 s
# [epoch 3,imgs  1040] loss: 0.7433003  time: 1.889 s
# [epoch 3,imgs  1080] loss: 0.7350152  time: 1.889 s
# [epoch 3,imgs  1120] loss: 0.7330729  time: 1.888 s
# [epoch 3,imgs  1160] loss: 0.7413830  time: 1.888 s
# [epoch 3,imgs  1200] loss: 0.7403831  time: 1.888 s
# [epoch 4,imgs    40] loss: 0.7397870  time: 2.252 s
# [epoch 4,imgs    80] loss: 0.7415079  time: 1.864 s
# [epoch 4,imgs   120] loss: 0.7430613  time: 1.872 s
# [epoch 4,imgs   160] loss: 0.7398145  time: 1.867 s
# [epoch 4,imgs   200] loss: 0.7382991  time: 1.866 s
# [epoch 4,imgs   240] loss: 0.7373044  time: 1.857 s
# [epoch 4,imgs   280] loss: 0.7373110  time: 1.865 s
# [epoch 4,imgs   320] loss: 0.7428100  time: 1.872 s
# [epoch 4,imgs   360] loss: 0.7421608  time: 1.874 s
# [epoch 4,imgs   400] loss: 0.7426997  time: 1.871 s
# [epoch 4,imgs   440] loss: 0.7375900  time: 1.875 s
# [epoch 4,imgs   480] loss: 0.7430968  time: 1.862 s
# [epoch 4,imgs   520] loss: 0.7428728  time: 1.868 s
# [epoch 4,imgs   560] loss: 0.7394372  time: 1.870 s
# [epoch 4,imgs   600] loss: 0.7370089  time: 1.633 s
# [epoch 4,imgs   640] loss: 0.7394949  time: 1.648 s
# [epoch 4,imgs   680] loss: 0.7377964  time: 1.871 s
# [epoch 4,imgs   720] loss: 0.7349975  time: 1.860 s
# [epoch 4,imgs   760] loss: 0.7400568  time: 1.870 s
# [epoch 4,imgs   800] loss: 0.7425295  time: 1.864 s
# [epoch 4,imgs   840] loss: 0.7396944  time: 1.868 s
# [epoch 4,imgs   880] loss: 0.7347797  time: 1.862 s
# [epoch 4,imgs   920] loss: 0.7343009  time: 1.863 s
# [epoch 4,imgs   960] loss: 0.7372962  time: 1.868 s
# [epoch 4,imgs  1000] loss: 0.7399747  time: 1.858 s
# [epoch 4,imgs  1040] loss: 0.7392554  time: 1.866 s
# [epoch 4,imgs  1080] loss: 0.7390767  time: 1.866 s
# [epoch 4,imgs  1120] loss: 0.7408532  time: 1.862 s
# [epoch 4,imgs  1160] loss: 0.7414145  time: 1.877 s
# [epoch 4,imgs  1200] loss: 0.7432224  time: 1.866 s
# [epoch 5,imgs    40] loss: 0.7430175  time: 2.269 s
# [epoch 5,imgs    80] loss: 0.7410772  time: 1.875 s
# [epoch 5,imgs   120] loss: 0.7414302  time: 1.873 s
# [epoch 5,imgs   160] loss: 0.7365889  time: 1.869 s
# [epoch 5,imgs   200] loss: 0.7399846  time: 1.871 s
# [epoch 5,imgs   240] loss: 0.7474467  time: 1.878 s
# [epoch 5,imgs   280] loss: 0.7436271  time: 1.871 s
# [epoch 5,imgs   320] loss: 0.7393268  time: 1.879 s
# [epoch 5,imgs   360] loss: 0.7407973  time: 1.872 s
# [epoch 5,imgs   400] loss: 0.7408373  time: 1.877 s
# [epoch 5,imgs   440] loss: 0.7389900  time: 1.873 s
# [epoch 5,imgs   480] loss: 0.7366006  time: 1.879 s
# [epoch 5,imgs   520] loss: 0.7408221  time: 1.869 s
# [epoch 5,imgs   560] loss: 0.7411323  time: 1.871 s
# [epoch 5,imgs   600] loss: 0.7390236  time: 1.830 s
# [epoch 5,imgs   640] loss: 0.7372083  time: 1.473 s
# [epoch 5,imgs   680] loss: 0.7429696  time: 1.878 s
# [epoch 5,imgs   720] loss: 0.7346121  time: 1.883 s
# [epoch 5,imgs   760] loss: 0.7344745  time: 1.886 s
# [epoch 5,imgs   800] loss: 0.7399322  time: 1.881 s
# [epoch 5,imgs   840] loss: 0.7386655  time: 1.885 s
# [epoch 5,imgs   880] loss: 0.7383378  time: 1.885 s
# [epoch 5,imgs   920] loss: 0.7412465  time: 1.875 s
# [epoch 5,imgs   960] loss: 0.7380511  time: 1.882 s
# [epoch 5,imgs  1000] loss: 0.7426230  time: 1.883 s
# [epoch 5,imgs  1040] loss: 0.7378048  time: 1.921 s
# [epoch 5,imgs  1080] loss: 0.7383709  time: 1.885 s
# [epoch 5,imgs  1120] loss: 0.7411663  time: 1.887 s
# [epoch 5,imgs  1160] loss: 0.7407793  time: 1.882 s
# [epoch 5,imgs  1200] loss: 0.7413367  time: 1.887 s
# [epoch 6,imgs    40] loss: 0.7382262  time: 2.260 s
# [epoch 6,imgs    80] loss: 0.7477959  time: 1.878 s
# [epoch 6,imgs   120] loss: 0.7394425  time: 1.879 s
# [epoch 6,imgs   160] loss: 0.7414183  time: 1.872 s
# [epoch 6,imgs   200] loss: 0.7389925  time: 1.877 s
# [epoch 6,imgs   240] loss: 0.7418320  time: 1.864 s
# [epoch 6,imgs   280] loss: 0.7403204  time: 1.876 s
# [epoch 6,imgs   320] loss: 0.7387974  time: 1.873 s
# [epoch 6,imgs   360] loss: 0.7378886  time: 1.877 s
# [epoch 6,imgs   400] loss: 0.7380273  time: 1.874 s
# [epoch 6,imgs   440] loss: 0.7445444  time: 1.877 s
# [epoch 6,imgs   480] loss: 0.7419638  time: 1.865 s
# [epoch 6,imgs   520] loss: 0.7380919  time: 1.888 s
# [epoch 6,imgs   560] loss: 0.7379001  time: 1.875 s
# [epoch 6,imgs   600] loss: 0.7379321  time: 1.877 s
# [epoch 6,imgs   640] loss: 0.7378625  time: 1.401 s
# [epoch 6,imgs   680] loss: 0.7401515  time: 1.875 s
# [epoch 6,imgs   720] loss: 0.7411832  time: 1.879 s
# [epoch 6,imgs   760] loss: 0.7374236  time: 1.870 s
# [epoch 6,imgs   800] loss: 0.7363732  time: 1.871 s
# [epoch 6,imgs   840] loss: 0.7407470  time: 1.873 s
# [epoch 6,imgs   880] loss: 0.7349895  time: 1.864 s
# [epoch 6,imgs   920] loss: 0.7362083  time: 1.877 s
# [epoch 6,imgs   960] loss: 0.7416428  time: 1.874 s
# [epoch 6,imgs  1000] loss: 0.7341807  time: 1.870 s
# [epoch 6,imgs  1040] loss: 0.7357588  time: 1.869 s
# [epoch 6,imgs  1080] loss: 0.7458131  time: 1.881 s
# [epoch 6,imgs  1120] loss: 0.7361494  time: 1.875 s
# [epoch 6,imgs  1160] loss: 0.7425807  time: 1.871 s
# [epoch 6,imgs  1200] loss: 0.7406490  time: 1.878 s
# [epoch 7,imgs    40] loss: 0.7422333  time: 2.305 s
# [epoch 7,imgs    80] loss: 0.7360162  time: 1.874 s
# [epoch 7,imgs   120] loss: 0.7413033  time: 1.876 s
# [epoch 7,imgs   160] loss: 0.7404991  time: 1.871 s
# [epoch 7,imgs   200] loss: 0.7447354  time: 1.879 s
# [epoch 7,imgs   240] loss: 0.7360023  time: 1.876 s
# [epoch 7,imgs   280] loss: 0.7409139  time: 1.878 s
# [epoch 7,imgs   320] loss: 0.7382116  time: 1.871 s
# [epoch 7,imgs   360] loss: 0.7419512  time: 1.885 s
# [epoch 7,imgs   400] loss: 0.7438839  time: 1.884 s
# [epoch 7,imgs   440] loss: 0.7442966  time: 1.870 s
# [epoch 7,imgs   480] loss: 0.7363628  time: 1.876 s
# [epoch 7,imgs   520] loss: 0.7404463  time: 1.880 s
# [epoch 7,imgs   560] loss: 0.7384802  time: 1.878 s
# [epoch 7,imgs   600] loss: 0.7423153  time: 1.880 s
# [epoch 7,imgs   640] loss: 0.7434562  time: 1.402 s
# [epoch 7,imgs   680] loss: 0.7384257  time: 1.870 s
# [epoch 7,imgs   720] loss: 0.7386031  time: 1.885 s
# [epoch 7,imgs   760] loss: 0.7394322  time: 1.878 s
# [epoch 7,imgs   800] loss: 0.7396569  time: 1.874 s
# [epoch 7,imgs   840] loss: 0.7411675  time: 1.876 s
# [epoch 7,imgs   880] loss: 0.7441598  time: 1.877 s
# [epoch 7,imgs   920] loss: 0.7401583  time: 1.874 s
# [epoch 7,imgs   960] loss: 0.7372884  time: 1.875 s
# [epoch 7,imgs  1000] loss: 0.7365716  time: 1.879 s
# [epoch 7,imgs  1040] loss: 0.7413422  time: 1.876 s
# [epoch 7,imgs  1080] loss: 0.7421405  time: 1.884 s
# [epoch 7,imgs  1120] loss: 0.7390813  time: 1.875 s
# [epoch 7,imgs  1160] loss: 0.7387582  time: 1.879 s
# [epoch 7,imgs  1200] loss: 0.7360893  time: 1.876 s
# [epoch 8,imgs    40] loss: 0.7389128  time: 2.302 s
# [epoch 8,imgs    80] loss: 0.7432224  time: 1.875 s
# [epoch 8,imgs   120] loss: 0.7398053  time: 1.886 s
# [epoch 8,imgs   160] loss: 0.7379672  time: 1.877 s
# [epoch 8,imgs   200] loss: 0.7394794  time: 1.882 s
# [epoch 8,imgs   240] loss: 0.7366053  time: 1.876 s
# [epoch 8,imgs   280] loss: 0.7432120  time: 1.875 s
# [epoch 8,imgs   320] loss: 0.7336776  time: 1.875 s
# [epoch 8,imgs   360] loss: 0.7389647  time: 1.877 s
# [epoch 8,imgs   400] loss: 0.7383104  time: 1.880 s
# [epoch 8,imgs   440] loss: 0.7362375  time: 1.872 s
# [epoch 8,imgs   480] loss: 0.7366319  time: 1.874 s
# [epoch 8,imgs   520] loss: 0.7445430  time: 1.867 s
# [epoch 8,imgs   560] loss: 0.7385728  time: 1.878 s
# [epoch 8,imgs   600] loss: 0.7344803  time: 1.841 s
# [epoch 8,imgs   640] loss: 0.7392247  time: 1.464 s
# [epoch 8,imgs   680] loss: 0.7428590  time: 1.911 s
# [epoch 8,imgs   720] loss: 0.7395855  time: 1.884 s
# [epoch 8,imgs   760] loss: 0.7394667  time: 1.890 s
# [epoch 8,imgs   800] loss: 0.7382331  time: 1.881 s
# [epoch 8,imgs   840] loss: 0.7428685  time: 1.896 s
# [epoch 8,imgs   880] loss: 0.7398592  time: 1.875 s
# [epoch 8,imgs   920] loss: 0.7361487  time: 1.869 s
# [epoch 8,imgs   960] loss: 0.7387898  time: 1.870 s
# [epoch 8,imgs  1000] loss: 0.7401252  time: 1.890 s
# [epoch 8,imgs  1040] loss: 0.7402421  time: 1.882 s
# [epoch 8,imgs  1080] loss: 0.7422367  time: 1.885 s
# [epoch 8,imgs  1120] loss: 0.7344512  time: 1.888 s
# [epoch 8,imgs  1160] loss: 0.7405295  time: 1.879 s
# [epoch 8,imgs  1200] loss: 0.7376899  time: 1.888 s
# [epoch 9,imgs    40] loss: 0.7353190  time: 2.280 s
# [epoch 9,imgs    80] loss: 0.7355868  time: 1.877 s
# [epoch 9,imgs   120] loss: 0.7418417  time: 1.879 s
# [epoch 9,imgs   160] loss: 0.7401544  time: 1.877 s
# [epoch 9,imgs   200] loss: 0.7360114  time: 1.881 s
# [epoch 9,imgs   240] loss: 0.7319207  time: 1.891 s
# [epoch 9,imgs   280] loss: 0.7399560  time: 1.879 s
# [epoch 9,imgs   320] loss: 0.7397259  time: 1.885 s
# [epoch 9,imgs   360] loss: 0.7441629  time: 1.881 s
# [epoch 9,imgs   400] loss: 0.7399635  time: 1.880 s
# [epoch 9,imgs   440] loss: 0.7422312  time: 1.879 s
# [epoch 9,imgs   480] loss: 0.7405592  time: 1.880 s
# [epoch 9,imgs   520] loss: 0.7406969  time: 1.877 s
# [epoch 9,imgs   560] loss: 0.7384009  time: 1.875 s
# [epoch 9,imgs   600] loss: 0.7411078  time: 1.743 s
# [epoch 9,imgs   640] loss: 0.7383575  time: 1.588 s
# [epoch 9,imgs   680] loss: 0.7376304  time: 1.889 s
# [epoch 9,imgs   720] loss: 0.7405177  time: 1.883 s
# [epoch 9,imgs   760] loss: 0.7381757  time: 1.884 s
# [epoch 9,imgs   800] loss: 0.7420799  time: 1.889 s
# [epoch 9,imgs   840] loss: 0.7381257  time: 1.894 s
# [epoch 9,imgs   880] loss: 0.7412119  time: 1.882 s
# [epoch 9,imgs   920] loss: 0.7410290  time: 1.882 s
# [epoch 9,imgs   960] loss: 0.7427645  time: 1.886 s
# [epoch 9,imgs  1000] loss: 0.7397053  time: 1.896 s
# [epoch 9,imgs  1040] loss: 0.7410622  time: 1.894 s
# [epoch 9,imgs  1080] loss: 0.7387708  time: 1.895 s
# [epoch 9,imgs  1120] loss: 0.7367691  time: 1.882 s
# [epoch 9,imgs  1160] loss: 0.7454352  time: 1.886 s
# [epoch 9,imgs  1200] loss: 0.7404538  time: 1.890 s
# [epoch 10,imgs    40] loss: 0.7371133  time: 2.325 s
# [epoch 10,imgs    80] loss: 0.7372952  time: 1.888 s
# [epoch 10,imgs   120] loss: 0.7415658  time: 1.892 s
# [epoch 10,imgs   160] loss: 0.7341595  time: 1.881 s
# [epoch 10,imgs   200] loss: 0.7384856  time: 1.901 s
# [epoch 10,imgs   240] loss: 0.7397134  time: 1.895 s
# [epoch 10,imgs   280] loss: 0.7340887  time: 1.891 s
# [epoch 10,imgs   320] loss: 0.7436393  time: 1.884 s
# [epoch 10,imgs   360] loss: 0.7410370  time: 1.883 s
# [epoch 10,imgs   400] loss: 0.7403524  time: 1.887 s
# [epoch 10,imgs   440] loss: 0.7397557  time: 1.893 s
# [epoch 10,imgs   480] loss: 0.7354604  time: 1.905 s
# [epoch 10,imgs   520] loss: 0.7396430  time: 1.887 s
# [epoch 10,imgs   560] loss: 0.7382687  time: 1.892 s
# [epoch 10,imgs   600] loss: 0.7408941  time: 1.356 s
# [epoch 10,imgs   640] loss: 0.7435617  time: 1.886 s
# [epoch 10,imgs   680] loss: 0.7393336  time: 1.898 s
# [epoch 10,imgs   720] loss: 0.7382535  time: 1.887 s
# [epoch 10,imgs   760] loss: 0.7363108  time: 1.895 s
# [epoch 10,imgs   800] loss: 0.7335889  time: 1.885 s
# [epoch 10,imgs   840] loss: 0.7394645  time: 1.881 s
# [epoch 10,imgs   880] loss: 0.7390561  time: 1.890 s
# [epoch 10,imgs   920] loss: 0.7407685  time: 1.880 s
# [epoch 10,imgs   960] loss: 0.7372198  time: 1.879 s
# [epoch 10,imgs  1000] loss: 0.7358109  time: 1.891 s
# [epoch 10,imgs  1040] loss: 0.7385668  time: 1.900 s
# [epoch 10,imgs  1080] loss: 0.7389290  time: 1.883 s
# [epoch 10,imgs  1120] loss: 0.7374012  time: 1.888 s
# [epoch 10,imgs  1160] loss: 0.7404621  time: 1.893 s
# [epoch 10,imgs  1200] loss: 0.7345890  time: 1.880 s
# [epoch 11,imgs    40] loss: 0.7436972  time: 2.300 s
# [epoch 11,imgs    80] loss: 0.7358158  time: 1.907 s
# [epoch 11,imgs   120] loss: 0.7422864  time: 1.900 s
# [epoch 11,imgs   160] loss: 0.7416186  time: 1.896 s
# [epoch 11,imgs   200] loss: 0.7410402  time: 1.890 s
# [epoch 11,imgs   240] loss: 0.7436470  time: 1.887 s
# [epoch 11,imgs   280] loss: 0.7383791  time: 1.885 s
# [epoch 11,imgs   320] loss: 0.7391133  time: 1.891 s
# [epoch 11,imgs   360] loss: 0.7382051  time: 1.905 s
# [epoch 11,imgs   400] loss: 0.7447348  time: 1.897 s
# [epoch 11,imgs   440] loss: 0.7407045  time: 1.891 s
# [epoch 11,imgs   480] loss: 0.7394589  time: 1.896 s
# [epoch 11,imgs   520] loss: 0.7373276  time: 1.881 s
# [epoch 11,imgs   560] loss: 0.7429159  time: 1.888 s
# [epoch 11,imgs   600] loss: 0.7382215  time: 1.371 s
# [epoch 11,imgs   640] loss: 0.7394947  time: 1.886 s
# [epoch 11,imgs   680] loss: 0.7397434  time: 1.875 s
# [epoch 11,imgs   720] loss: 0.7385093  time: 1.870 s
# [epoch 11,imgs   760] loss: 0.7406848  time: 1.880 s
# [epoch 11,imgs   800] loss: 0.7372956  time: 1.885 s
# [epoch 11,imgs   840] loss: 0.7374759  time: 1.880 s
# [epoch 11,imgs   880] loss: 0.7410815  time: 1.871 s
# [epoch 11,imgs   920] loss: 0.7411835  time: 1.880 s
# [epoch 11,imgs   960] loss: 0.7434812  time: 1.877 s
# [epoch 11,imgs  1000] loss: 0.7386857  time: 1.881 s
# [epoch 11,imgs  1040] loss: 0.7387822  time: 1.893 s
# [epoch 11,imgs  1080] loss: 0.7396420  time: 1.882 s
# [epoch 11,imgs  1120] loss: 0.7394116  time: 1.870 s
# [epoch 11,imgs  1160] loss: 0.7390290  time: 1.880 s
# [epoch 11,imgs  1200] loss: 0.7353572  time: 1.873 s
# [epoch 12,imgs    40] loss: 0.7386200  time: 2.298 s
# [epoch 12,imgs    80] loss: 0.7397242  time: 1.881 s
# [epoch 12,imgs   120] loss: 0.7375766  time: 1.899 s
# [epoch 12,imgs   160] loss: 0.7385173  time: 1.869 s
# [epoch 12,imgs   200] loss: 0.7400184  time: 1.870 s
# [epoch 12,imgs   240] loss: 0.7397677  time: 1.870 s
# [epoch 12,imgs   280] loss: 0.7347645  time: 1.869 s
# [epoch 12,imgs   320] loss: 0.7371920  time: 1.874 s
# [epoch 12,imgs   360] loss: 0.7407769  time: 1.873 s
# [epoch 12,imgs   400] loss: 0.7420862  time: 1.869 s
# [epoch 12,imgs   440] loss: 0.7386218  time: 1.860 s
# [epoch 12,imgs   480] loss: 0.7430486  time: 1.865 s
# [epoch 12,imgs   520] loss: 0.7366483  time: 1.868 s
# [epoch 12,imgs   560] loss: 0.7372352  time: 1.850 s
# [epoch 12,imgs   600] loss: 0.7383559  time: 1.339 s
# [epoch 12,imgs   640] loss: 0.7363217  time: 1.868 s
# [epoch 12,imgs   680] loss: 0.7376797  time: 1.869 s

# %%
#feat,lbls = extract_features(model,train_data_loader)
test_feat,test_lbls = extract_features(model,test_data_loader)
lbls = flatten_list(lbls)
test_lbls  =flatten_list(test_lbls) # flatting the lbls

# %%
feat.shape,len(lbls),test_feat.shape,len(test_lbls)
# Out:
# ((4835, 1536), 4835, (1854, 1536), 1854)

# %%
from sklearn import metrics
print('Train-Without FFT')
#SVM
svm_preds = SVC(kernel='linear').fit(feat,lbls).predict(test_feat)
print("SVM Accuracy:",metrics.accuracy_score(test_lbls, svm_preds))
# Out:
# Train-Without FFT
# SVM Accuracy: 0.4854368932038835

# %%
#save np network features and labels
# Use pickle for serialization or np.save for saving np objects. two options



i = 0 #video index 4797
j = 0 # neuron index 1000

def hstft(S1):
    S21, S22 = np.split(S1,2)  # 500+500
    S311, S312 = np.split(S21,2) # 500    
    S321, S322 = np.split(S22,2) # 500
    #S1.shape,S21.shape,S22.shape,S311.shape,S312.shape,S321.shape,S322.shape    
    return np.concatenate((S1,S21,S22,S311,S312,S321,S322))

def alpha(features):
    A = np.zeros((len(features),4608))
    for i,f in enumerate(features):
        h = scipy.fft.fft(f)    
        #print(f.shape,h.shape)
        #print(h.shape)
        h = hstft(h)
        #print(h.shape)
        A[i,:] = h.real
    return A

train_alpha = alpha(feat)
test_alpha = alpha(test_feat)
train_alpha.shape,test_alpha.shape
# Out:
# ((4835, 4608), (1854, 4608))

# %%
X = train_alpha
Y = lbls
test_x = test_alpha
test_y = test_lbls
X.shape,Y.shape,test_x.shape,test_y.shape
# Out:
# ((4835, 4608), (4835,), (1854, 4608), (1854,))

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

#SVM
clf = SVC(kernel='linear').fit(X,Y)
preds = clf.predict(test_x)
print("SVM Accuracy:",metrics.accuracy_score(test_y, preds))

#KNN

knn_clf = KNeighborsClassifier(n_neighbors=3).fit(X,Y)
knn_preds = knn_clf.predict(test_x)
print("KNN Accuracy:",metrics.accuracy_score(test_y, knn_preds))

#Random Forest
rf_clf = RandomForestClassifier(n_estimators=100).fit(X,Y)
rf_preds = rf_clf.predict(test_x)
print("RF Accuracy:",metrics.accuracy_score(test_y, rf_preds))
# Out:
# SVM Accuracy: 0.45792880258899676
# KNN Accuracy: 0.27993527508090615
# RF Accuracy: 0.4039913700107875
